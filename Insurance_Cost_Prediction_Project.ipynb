# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmed-loutfy/Insurance-Cost-Prediction-Project/blob/main/Insurance_Cost_Prediction_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
ins=pd.read_csv('/content/insurance.csv')

# %%
ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
ins.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
ins.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
ins.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
ins['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

# %%
sn.pairplot(ins,hue='smoker')

# %%
ins.hist(figsize=(10,15) , bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe76f88bf10>,
# ...
#       dtype=object)

# %%
plt.scatter(ins['smoker'],ins['charges'],alpha=0.6)
plt.title('the relation between smokers & charges')
plt.xlabel('smokers')
# Out:
# Text(0.5, 0, 'smokers')

# %%
plt.scatter(ins.bmi,ins.charges,alpha=0.6,linewidths=9,edgecolors='red')
plt.xlabel('bmi')
plt.title('relation between BMI & CHARGES')
# Out:
# Text(0.5, 1.0, 'relation between BMI & CHARGES')

# %%
plt.scatter(ins.bmi,ins.children,alpha=0.6,linewidths=9,edgecolors='blue',marker='x')
plt.xlabel('bmi')
plt.title('relation between BMI & children')
# Out:
# Text(0.5, 1.0, 'relation between BMI & children')

# %%
plt.hist(ins.charges,label='charges',color='red')
plt.hist(ins.children,label='children',color='blue')
# Out:
# (array([574.,   0., 324.,   0., 240.,   0., 157.,   0.,  25.,  18.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <a list of 10 Patch objects>)

# %%
sn.histplot(ins.charges,)

# %%
sn.histplot(ins.smoker)

# %%
sn.histplot(ins.sex)

# %%
sn.histplot(ins.smoker)

# %%
sn.histplot(ins.bmi)

# %%
sn.distplot(ins.charges,)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sn.countplot(data=ins,x=ins.children)

# %%
ins['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
sn.countplot(x=ins.age)

# %%
Corr=ins.corr()
plt.figure(figsize=(10,8))
sn.heatmap(Corr,cmap="BuPu",linewidths=0.005)

# %%
ins.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
ins['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
ins['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
ins['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
ins=pd.read_csv('/content/insurance.csv')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
insr=le.fit_transform(ins.region)
insm=le.fit_transform(ins.smoker)
inss=le.fit_transform(ins.sex)

# %%
ins.region=insr
ins.smoker=insm
ins.sex=inss

# %%
ins.region.value_counts()
# Out:
# 2    364
# 3    325
# 1    325
# 0    324
# Name: region, dtype: int64

# %%
ins.smoker.value_counts()
# Out:
# 0    1064
# 1     274
# Name: smoker, dtype: int64

# %%
ins.sex.value_counts()
# Out:
# 1    676
# 0    662
# Name: sex, dtype: int64

# %%
ins
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   region    1338 non-null   int64
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(5)
# memory usage: 73.3 KB

# %%
Corr=ins.corr(method='kendall')
plt.figure(figsize=(10,8))
sn.heatmap(Corr,cmap="BuPu",linewidths=0.005)

# %%
Corr=ins.corr()
Corr
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.042469 -0.025019  0.002127  0.299008
# sex      -0.020856  1.000000  0.046371  0.017163  0.076185  0.004588  0.057292
# bmi       0.109272  0.046371  1.000000  0.012759  0.003750  0.157566  0.198341
# children  0.042469  0.017163  0.012759  1.000000  0.007673  0.016569  0.067998
# smoker   -0.025019  0.076185  0.003750  0.007673  1.000000 -0.002181  0.787251
# region    0.002127  0.004588  0.157566  0.016569 -0.002181  1.000000 -0.006208
# charges   0.299008  0.057292  0.198341  0.067998  0.787251 -0.006208  1.000000

# %%
sn.distplot(ins)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from scipy import stats
ins=ins[(np.abs(stats.zscore(ins))<3).all(axis=1)]
ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1309 non-null   int64
#  1   sex       1309 non-null   int64
#  2   bmi       1309 non-null   float64
#  3   children  1309 non-null   int64
#  4   smoker    1309 non-null   int64
#  5   region    1309 non-null   int64
#  6   charges   1309 non-null   float64
# dtypes: float64(2), int64(5)
# memory usage: 81.8 KB

# %%
ins = ins.drop("children",axis=1)

# %%
ins
# Out:
#       age  sex     bmi  smoker  region      charges
# 0      19    0  27.900       1       3  16884.92400
# 1      18    1  33.770       0       2   1725.55230
# 2      28    1  33.000       0       2   4449.46200
# 3      33    1  22.705       0       1  21984.47061
# 4      32    1  28.880       0       1   3866.85520
# ...   ...  ...     ...     ...     ...          ...
# 1333   50    1  30.970       0       1  10600.54830
# 1334   18    0  31.920       0       0   2205.98080
# 1335   18    0  36.850       0       2   1629.83350
# 1336   21    0  25.800       0       3   2007.94500
# 1337   61    0  29.070       1       1  29141.36030
#
# [1309 rows x 6 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaling=MinMaxScaler()
ins = pd.DataFrame(scaling.fit_transform(ins),columns=['age','sex','bmi','smoker','region','charges'],index=ins.index)
ins
# Out:
#            age  sex       bmi  smoker    region   charges
# 0     0.021739  0.0  0.371847     1.0  1.000000  0.325308
# 1     0.000000  1.0  0.554656     0.0  0.666667  0.012458
# 2     0.217391  1.0  0.530676     0.0  0.666667  0.068673
# 3     0.326087  1.0  0.210059     0.0  0.333333  0.430549
# 4     0.304348  1.0  0.402367     0.0  0.333333  0.056649
# ...        ...  ...       ...     ...       ...       ...
# 1333  0.695652  1.0  0.467456     0.0  0.333333  0.195615
# 1334  0.000000  0.0  0.497041     0.0  0.000000  0.022373
# 1335  0.000000  0.0  0.650576     0.0  0.666667  0.010483
# 1336  0.065217  0.0  0.306447     0.0  1.000000  0.018286
# 1337  0.934783  0.0  0.408284     1.0  0.333333  0.578248
#
# [1309 rows x 6 columns]

# %%
sn.distplot(ins.charges,color = "darkblue")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.model_selection import train_test_split

# %%
train_set,test_set= train_test_split(ins,test_size=0.1)

# %%
train_set_x=train_set.drop(["charges"],axis=1)
train_set_y=train_set["charges"]

test_set_x = test_set.drop(["charges"],axis=1)
test_set_y = test_set["charges"]

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(train_set_x, train_set_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
some_data = train_set_x.iloc[:5]
some_labels = train_set_y.iloc[:5]
print("Predictions:", lin_reg.predict(some_data))
print("Labels:", list(some_labels))
# Out:
# Predictions: [0.57384793 0.27199694 0.08715801 0.07053165 0.48445927]
# Labels: [0.3838100952582786, 0.25398743640298, 0.3649280931626982, 0.11993135453775558, 0.2865437954848263]

# %%
from sklearn.metrics import mean_squared_error
ins_predictions = lin_reg.predict(train_set_x)
lin_mse = mean_squared_error(train_set_y, ins_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 0.12011444054194918
